# %%
import pandas as pd

# Load the sales dataset
df= pd.read_csv(r"C:\Users\Harsh\Desktop\sales_data.csv")

# %%
df
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
# CREATE: Insert a new record using pd.concat
new_record = pd.DataFrame([{
    'Product_ID': 1100,
    'Sale_Date': '2025-06-29',
    'Sales_Rep': 'Alice',
    'Region': 'Central',
    'Sales_Amount': 5000.00,
    'Quantity_Sold': 25,
    'Product_Category': 'Electronics',
    'Unit_Cost': 200.00,
    'Unit_Price': 300.00,
    'Customer_Type': 'New',
    'Discount': 0.05,
    'Payment_Method': 'Online Transfer',
    'Sales_Channel': 'Online',
    'Region_and_Sales_Rep': 'Central-Alice'
}])

# Concatenate the new record to the existing DataFrame
df = pd.concat([df, new_record], ignore_index=True)

# %%
### READ OPERATION ###
# Retrieve specific records: all sales made by 'Bob'
bob_sales = df[df['Sales_Rep'] == 'Bob']
print("Sales by Bob:")
print(bob_sales)
# Out:
# Sales by Bob:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 6          1083  2023-04-11       Bob   West        618.31             29
# 11         1100  2023-08-14       Bob   West       2198.74             43
# ..          ...         ...       ...    ...           ...            ...
# 971        1056  2023-12-27       Bob   East       7979.67              4
# 981        1028  2023-11-01       Bob   East       7946.69             24
# 982        1074  2023-12-16       Bob  North       6310.56             19
# 990        1017  2023-01-20       Bob   East        496.59             29
# 996        1067  2023-09-07       Bob  North       4716.36             37
#
# ...

# %%
### UPDATE OPERATION ###
# Increase discount to 0.10 for all 'New' customers in 'Electronics'
df.loc[(df['Customer_Type'] == 'New') & (df['Product_Category'] == 'Electronics'), 'Discount'] = 0.10

# %%
### DELETE OPERATION ###
# Delete all records where 'Quantity_Sold' is less than 10
df = df[df['Quantity_Sold'] >= 10]

# %%
### Save the updated DataFrame to a new CSV file
df.to_csv('updated_sales_data.csv', index=False)
print("\nCRUD operations completed. Updated dataset saved as 'updated_sales_data.csv'")
# Out:
# CRUD operations completed. Updated dataset saved as 'updated_sales_data.csv'
